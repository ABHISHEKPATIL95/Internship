# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\anaconda soft\lib\site-packages (3.1.1)
# Requirement already satisfied: alembic>=1.5.0 in c:\anaconda soft\lib\site-packages (from optuna) (1.10.3)
# Requirement already satisfied: numpy in c:\anaconda soft\lib\site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda soft\lib\site-packages (from optuna) (22.0)
# Requirement already satisfied: tqdm in c:\anaconda soft\lib\site-packages (from optuna) (4.64.1)
# Requirement already satisfied: cmaes>=0.9.1 in c:\anaconda soft\lib\site-packages (from optuna) (0.9.1)
# Requirement already satisfied: PyYAML in c:\anaconda soft\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: colorlog in c:\anaconda soft\lib\site-packages (from optuna) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\anaconda soft\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: Mako in c:\anaconda soft\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in c:\anaconda soft\lib\site-packages (from alembic>=1.5.0->optuna) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\anaconda soft\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\anaconda soft\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\anaconda soft\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: wheel in c:\anaconda soft\lib\site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: scipy in c:\anaconda soft\lib\site-packages (from lightgbm) (1.10.0)
# Requirement already satisfied: numpy in c:\anaconda soft\lib\site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\anaconda soft\lib\site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda soft\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda soft\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.1)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5

# %%
import os 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import joblib
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier, XGBRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')

# %%
 print(data.shape)

data.head()
# Out:
# (213, 11)
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
data.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
data.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        213 non-null    int64
#  1   1.52101  213 non-null    float64
#  2   13.64    213 non-null    float64
#  3   4.49     213 non-null    float64
#  4   1.10     213 non-null    float64
#  5   71.78    213 non-null    float64
#  6   0.06     213 non-null    float64
#  7   8.75     213 non-null    float64
#  8   0.00     213 non-null    float64
#  9   0.00.1   213 non-null    float64
#  10  1.1      213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
for col in data:
    print(col, data[col].nunique())
# Out:
# 1 213
# 1.52101 177
# 13.64 142
# 4.49 93
# 1.10 117
# 71.78 132
# 0.06 65
# 8.75 143
# 0.00 34
# 0.00.1 32
# 1.1 6

# %%
print(data.columns)
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
data["Type"] = data["Type"].astype("category")
data.info(memory_usage="deep")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 data["Type"] = data["Type"].astype("category")
#       2 data.info(memory_usage="deep")
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Type'

# %%
data.drop(index = 39, axis = 0, inplace = True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_e8e42_row0_col0, #T_e8e42_row1_col1, #T_e8e42_row2_col2, #T_e8e42_row3_col3, #T_e8e42_row4_col4, #T_e8e42_row5_col5, #T_e8e42_row6_col6, #T_e8e42_row7_col7, #T_e8e42_row8_col8, #T_e8e42_row9_col9, #T_e8e42_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e8e42_row0_col1, #T_e8e42_row2_col5, #T_e8e42_row10_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e8e42_row0_col2, #T_e8e42_row5_col10 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e8e42_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e8e42_row0_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_e8e42_row0_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_e8e42_row0_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e8e42_row0_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e8e42_row0_col8 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_e8e42_row0_col9, #T_e8e42_row4_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e8e42_row0_col10 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col0, #T_e8e42_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e8e42_row1_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col5, #T_e8e42_row2_col9, #T_e8e42_row3_col0, #T_e8e42_row3_col2, #T_e8e42_row3_col4, #T_e8e42_row3_col7, #T_e8e42_row3_col8, #T_e8e42_row3_col10, #T_e8e42_row5_col1, #T_e8e42_row7_col2, #T_e8e42_row7_col6, #T_e8e42_row10_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col7 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_e8e42_row1_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e8e42_row1_col9, #T_e8e42_row9_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e8e42_row1_col10, #T_e8e42_row5_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_e8e42_row2_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_e8e42_row2_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e8e42_row2_col3, #T_e8e42_row3_col1, #T_e8e42_row3_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e8e42_row2_col4, #T_e8e42_row5_col0, #T_e8e42_row7_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e8e42_row2_col6, #T_e8e42_row10_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e8e42_row2_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e8e42_row2_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e8e42_row2_col10, #T_e8e42_row10_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_e8e42_row3_col5, #T_e8e42_row10_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e8e42_row3_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e8e42_row4_col0 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_e8e42_row4_col1, #T_e8e42_row6_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e8e42_row4_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e8e42_row4_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e8e42_row4_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e8e42_row4_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e8e42_row4_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e8e42_row4_col8 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_e8e42_row4_col10 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_e8e42_row5_col2, #T_e8e42_row5_col7, #T_e8e42_row6_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e8e42_row5_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e8e42_row5_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e8e42_row5_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e8e42_row5_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e8e42_row6_col0, #T_e8e42_row9_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_e8e42_row6_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e8e42_row6_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e8e42_row6_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_e8e42_row6_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e8e42_row6_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e8e42_row6_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e8e42_row6_col10 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_e8e42_row7_col0, #T_e8e42_row10_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_e8e42_row7_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_e8e42_row7_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e8e42_row7_col4, #T_e8e42_row8_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e8e42_row7_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e8e42_row7_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e8e42_row7_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e8e42_row8_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_e8e42_row8_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e8e42_row8_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e8e42_row8_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e8e42_row8_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e8e42_row8_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e8e42_row8_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e8e42_row8_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e8e42_row8_col10 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_e8e42_row9_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e8e42_row9_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e8e42_row9_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e8e42_row9_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_e8e42_row9_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e8e42_row9_col5, #T_e8e42_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e8e42_row9_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e8e42_row10_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_e8e42_row10_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_e8e42_row10_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_e8e42_row10_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8e42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8e42_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e8e42_level0_col1" class="col_heading level0 col1" >1.52101</th>
#       <th id="T_e8e42_level0_col2" class="col_heading level0 col2" >13.64</th>
#       <th id="T_e8e42_level0_col3" class="col_heading level0 col3" >4.49</th>
#       <th id="T_e8e42_level0_col4" class="col_heading level0 col4" >1.10</th>
#       <th id="T_e8e42_level0_col5" class="col_heading level0 col5" >71.78</th>
#       <th id="T_e8e42_level0_col6" class="col_heading level0 col6" >0.06</th>
#       <th id="T_e8e42_level0_col7" class="col_heading level0 col7" >8.75</th>
#       <th id="T_e8e42_level0_col8" class="col_heading level0 col8" >0.00</th>
#       <th id="T_e8e42_level0_col9" class="col_heading level0 col9" >0.00.1</th>
#       <th id="T_e8e42_level0_col10" class="col_heading level0 col10" >1.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e42_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e8e42_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e8e42_row0_col1" class="data row0 col1" >-0.066628</td>
#       <td id="T_e8e42_row0_col2" class="data row0 col2" >0.378453</td>
#       <td id="T_e8e42_row0_col3" class="data row0 col3" >-0.646448</td>
#       <td id="T_e8e42_row0_col4" class="data row0 col4" >0.486967</td>
#       <td id="T_e8e42_row0_col5" class="data row0 col5" >0.055316</td>
#       <td id="T_e8e42_row0_col6" class="data row0 col6" >-0.001198</td>
#       <td id=

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv")

if 'Type' not in data.columns:
    print("Column 'Type' does not exist in the DataFrame.")
else:
    print("Column 'Type' exists in the DataFrame.")
# Out:
# Column 'Type' does not exist in the DataFrame.

# %%
sns.countplot(x = data['Type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 sns.countplot(x = data['Type'])
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File C:\ANACONDA SOFT\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Type'

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')
print(data.columns)
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')
